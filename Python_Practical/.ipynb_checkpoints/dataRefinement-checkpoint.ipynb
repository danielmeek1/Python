# %%
import pandas as pd
import re

# %%
pd.set_option('max_colwidth', 400)

# %%
df = pd.read_csv('./data/CometLanding.csv')

# %%
''' Removes duplicates along with other basic data cleaning '''
def basicDataCleaning(df):
    df = df.drop_duplicates(subset=['status_url'], keep='first')
    df = df.replace({r'[^\x00-\x7F]+':''}, regex=True)
    #df = df.dropna()
    return df

# %%
df = basicDataCleaning(df)

# %%
''' Removes usernames that are not valid from the data set (according to Twitter specifications) '''
''' Usernames that are longer than 15 Characters are not valid '''
''' Usernames that are not alphanumeric are not valid with the exception of underscores '''
''' Usernames containing the words Twitter or Admin cannot be claimed. '''

def validateUserName(df):
    
    df = df.drop(df[df['from_user'].str.len() > 15].index)  
    df = df.drop(df[df['from_user'].apply(lambda x: re.search(r'[a-zA-Z0-9_]', x)) == None].index)
    df = df.drop(df[df['from_user'].apply(lambda x: re.search('Twitter', x, re.IGNORECASE) != None)].index)
    df = df.drop(df[df['from_user'].apply(lambda x: re.search('Admin', x, re.IGNORECASE) != None)].index)                 
    return df

# %%
df = validateUserName(df)

# %%
''' Refines language data '''
''' Turns data such as en-gb to en only to achieve consistency'''
''' Turns all data lower-case to achieve consistency'''

def refineLanguageData(df):
    df['user_lang'] = df['user_lang'].str.lower()
    df['user_lang'] = df["user_lang"].replace({'en-gb':'en'}, regex=True)
    return df

# %%
df = refineLanguageData(df)

# %%
'''Removes the data that do not follow twitter specifications for tweet length'''
'''A tweet could contain maximum 140 characters before November 8th 2017'''
'''Any data that do not match this specification is questionable'''
def validateTweetLength(df):
    
    df = df.drop(df[df['text'].str.len() > 140].index)
    return df

# %%
df = validateTweetLength(df)

# %%
df
# Out:
#              id_str        from_user  \
# 2      5.409300e+17         MHuuskoL
# 3      5.409293e+17  SaraGomezAranci
# 4      5.409292e+17          CBCDay6
# 5      5.409287e+17      MBernacconi
# 6      5.409285e+17        LukeGolds
# ...             ...              ...
# 77314  5.324601e+17     ABForScience
# 77315  5.324601e+17           atieyK
# 77316  5.324601e+17           j0nny5
# 77317  5.324601e+17          nsentse
# 77318  5.324601e+17          grery92
#
#                                                                                                                                                       text  \
# 2              RT @EUCouncil: After the #CometLanding - Astronaut @astro_luca discussed space policy with ministers today: http://t.co/ZjKAgpXhkt http://t
# 3              RT @EUCouncil: After the #CometLanding - Astronaut @astro_luca discussed space policy with ministers today: http://t.co/ZjKAgpXhkt http://t
# 4              RT @shaunmajumder: Feels good to be the @CBCDay6 champion beating #MiniMansbridge @davidcommon and @SusanKent #CometLanding #LetItSnow #MtR
# 5              RT @EUCouncil: After the #CometLanding - Astronaut @astro_luca discussed space policy with ministers today: http://t.co/ZjKAgpXhkt http://t
# 6                 USA  NEWS   HOT NEWS 828 comet landing Philae touches down on the surface of a comet #cometlanding heyyouapp T... http://t.co/C4XSjBq7G2
# ...                                                                                                                                                    ...
# 77314                                               This means  that the actual landing will be around 3am aus Eastern daylight savings time #CometLanding
# 77315            RT @ObservingSpace: Weve been waiting 10 years.. we see it in the telemetry. Separation went flawlessly  Andrea Accomazzo #cometlanding h
# 77316            RT @maxplanckpress: Accomazzo (flight director): "Separation worked out definitely - philae is gone towards the comet" #CometLanding (fm)
# 77317                                                                                                                     7 hours of waiting #CometLanding
# 77318  RT @dsdanyds: TopTrendIT: TT ITALIA 09:59\n1.#GUERRIERO\n2.#portaaporta\n3.#CometLanding\n4.#TorSapienza\n5.#Rosetta\n6.USA e Cina\n7.Salvini\n8.Ro
#
#                            created_at              time geo_coordinates  \
# 2      Fri Dec 05 18:05:36 +0000 2014  05/12/2014 18:05             NaN
# 3      Fri Dec 05 18:03:00 +0000 2014  05/12/2014 18:03             NaN
# 4      Fri Dec 05 18:02:32 +0000 2014  05/12/2014 18:02             NaN
# 5      Fri Dec 05 18:00:28 +0000 2014  05/12/2014 18:00             NaN
# 6      Fri Dec 05 17:59:42 +0000 2014  05/12/2014 17:59             NaN
# ...                               ...               ...             ...
# 77314  Wed Nov 12 09:09:26 +0000 2014  12/11/2014 09:09             NaN
# 77315  Wed Nov 12 09:09:26 +0000 2014  12/11/2014 09:09             NaN
# 77316  Wed Nov 12 09:09:26 +0000 2014  12/11/2014 09:09             NaN
# 77317  Wed Nov 12 09:09:26 +0000 2014  12/11/2014 09:09             NaN
# 77318  Wed Nov 12 09:09:26 +0000 2014  12/11/2014 09:09             NaN
#
#       user_lang  in_reply_to_user_id_str in_reply_to_screen_name  \
# 2            en                      NaN                     NaN
# 3            fr                      NaN                     NaN
# 4            en                      NaN                     NaN
# 5            en                      NaN                     NaN
# 6            en                      NaN                     NaN
# ...         ...                      ...                     ...
# 77314        en                      NaN                     NaN
# 77315        en                      NaN                     NaN
# 77316        en                      NaN                     NaN
# 77317        en                      NaN                     NaN
# 77318        it                      NaN                     NaN
#
#        from_user_id_str  in_reply_to_status_id_str  \
# 2          5.744348e+08                        NaN
# 3          1.057356e+09                        NaN
# 4          1.772769e+08                        NaN
# 5          4.790749e+07                        NaN
# 6          6.196297e+08                        NaN
# ...                 ...                        ...
# 77314      2.333123e+09                        NaN
# 77315      5.830372e+07                        NaN
# 77316      1.791486e+07                        NaN
# 77317      2.043400e+07                        NaN
# 77318      4.878276e+08                        NaN
#
#                                                                                               source  \
# 2                  <a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>
# 3                 <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4               <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 5                                 <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 6                                                <a href="http://ifttt.com" rel="nofollow">IFTTT</a>
# ...                                                                                              ...
# 77314                <a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>
# 77315  <a href="https://twitter.com/download/android" rel="nofollow">Twitter for Android Tablets</a>
# 77316                             <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 77317             <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 77318           <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                          profile_image_url  \
# 2                              http://pbs.twimg.com/profile_images/497351058826756096/UMRFSFMf_normal.jpeg
# 3                              http://pbs.twimg.com/profile_images/539170580478828544/d0diSAVk_normal.jpeg
# 4                              http://pbs.twimg.com/profile_images/459069430371086336/VvLJFxdc_normal.jpeg
# 5                              http://pbs.twimg.com/profile_images/533194305905491968/TDcZsosT_normal.jpeg
# 6                          http://pbs.twimg.com/profile_images/2344739619/zkh6mdlcodzt9j64znty_normal.jpeg
# ...                                                                                                    ...
# 77314                           http://pbs.twimg.com/profile_images/432069559336448000/ig-lYPQp_normal.png
# 77315                          http://pbs.twimg.com/profile_images/505731163713843200/yyQvaSgE_normal.jpeg
# 77316                                       http://pbs.twimg.com/profile_images/89991673/jonnnn_normal.jpg
# 77317          http://pbs.twimg.com/profile_images/3693655850/1d56869aa53a8c796d68e5cc0308bca6_normal.jpeg
# 77318  http://pbs.twimg.com/profile_images/378800000443751322/45164a083866ef492d2b1edd4174bf38_normal.jpeg
#
#        user_followers_count  user_friends_count  \
# 2                     215.0               310.0
# 3                     741.0               310.0
# 4                    4331.0              2098.0
# 5                     317.0               478.0
# 6                     350.0                 NaN
# ...                     ...                 ...
# 77314                 155.0               212.0
# 77315                 354.0              1088.0
# 77316                  92.0                63.0
# 77317                 200.0               267.0
# 77318                 194.0               403.0
#
#                                                            status_url  \
# 2             http://twitter.com/MHuuskoL/statuses/540929998388211713
# 3      http://twitter.com/SaraGomezAranci/statuses/540929346878599168
# 4              http://twitter.com/CBCDay6/statuses/540929229052203008
# 5          http://twitter.com/MBernacconi/statuses/540928707947671555
# 6            http://twitter.com/LukeGolds/statuses/540928513906589696
# ...                                                               ...
# 77314     http://twitter.com/ABForScience/statuses/532460149084930049
# 77315           http://twitter.com/atieyK/statuses/532460148451581952
# 77316           http://twitter.com/j0nny5/statuses/532460148254470144
# 77317          http://twitter.com/nsentse/statuses/532460148238090240
# 77318          http://twitter.com/grery92/statuses/532460147764125696
#
#                                                                                                                                                                                                                                                                                                                                                                                                           entities_str
# 2      {"hashtags":[{"text":"CometLanding","indices":[25,38]}],"symbols":[],"user_mentions":[{"screen_name":"EUCouncil","name":"EU Council","id":206717989,"id_str":"206717989","indices":[3,13]},{"screen_name":"astro_luca","name":"Luca Parmitano","id":290876018,"id_str":"290876018","indices":[51,62]}],"urls":[{"url":"http://t.co/ZjKAgpXhkt","expanded_url":"http://ow.ly/FqZCE","display_url":"ow.ly/FqZC...
# 3      {"hashtags":[{"text":"CometLanding","indices":[25,38]}],"symbols":[],"user_mentions":[{"screen_name":"EUCouncil","name":"EU Council","id":206717989,"id_str":"206717989","indices":[3,13]},{"screen_name":"astro_luca","name":"Luca Parmitano","id":290876018,"id_str":"290876018","indices":[51,62]}],"urls":[{"url":"http://t.co/ZjKAgpXhkt","expanded_url":"http://ow.ly/FqZCE","display_url":"ow.ly/FqZC...
# 4      {"hashtags":[{"text":"MiniMansbridge","indices":[66,81]},{"text":"CometLanding","indices":[110,123]},{"text":"LetItSnow","indices":[124,134]},{"text":"MtRushmore","indices":[135,140]}],"symbols":[],"user_mentions":[{"screen_name":"shaunmajumder","name":"Shaun Majumder","id":17680518,"id_str":"17680518","indices":[3,17]},{"screen_name":"CBCDay6","name":"CBC Day 6","id":177276897,"id_str":"17727...
# 5      {"hashtags":[{"text":"CometLanding","indices":[25,38]}],"symbols":[],"user_mentions":[{"screen_name":"EUCouncil","name":"EU Council","id":206717989,"id_str":"206717989","indices":[3,13]},{"screen_name":"astro_luca","name":"Luca Parmitano","id":290876018,"id_str":"290876018","indices":[51,62]}],"urls":[{"url":"http://t.co/ZjKAgpXhkt","expanded_url":"http://ow.ly/FqZCE","display_url":"ow.ly/FqZC...
# 6                                                                                                                                                                                        {"hashtags":[{"text":"cometlanding","indices":[87,100]}],"symbols":[],"user_mentions":[],"urls":[{"url":"http://t.co/C4XSjBq7G2","expanded_url":"http://dlvr.it/7knHzd","display_url":"dlvr.it/7knHzd","indices":[116,138]}]}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 77314                                                                                                                                                                                                                                                                                                              {"hashtags":[{"text":"CometLanding","indices":[89,102]}],"symbols":[],"user_mentions":[],"urls":[]}
# 77315  {"hashtags":[{"text":"cometlanding","indices":[124,137]}],"symbols":[],"user_mentions":[{"screen_name":"ObservingSpace","name":"Observing Space","id":1041442471,"id_str":"1041442471","indices":[3,18]}],"urls":[],"media":[{"id":532460012690354200,"id_str":"532460012690354176","indices":[139,140],"media_url":"http://pbs.twimg.com/media/B2Otj3mCMAAiq3S.png","media_url_https":"https://pbs.twimg.co...
# 77316                                                                                                                                                                                            {"hashtags":[{"text":"CometLanding","indices":[119,132]}],"symbols":[],"user_mentions":[{"screen_name":"maxplanckpress","name":"Max Planck Society","id":205195655,"id_str":"205195655","indices":[3,18]}],"urls":[]}
# 77317                                                                                                                                                                                                                                                                                                               {"hashtags":[{"text":"CometLanding","indices":[19,32]}],"symbols":[],"user_mentions":[],"urls":[]}
# 77318                                       {"hashtags":[{"text":"GUERRIERO","indices":[44,54]},{"text":"portaaporta","indices":[57,69]},{"text":"CometLanding","indices":[72,85]},{"text":"TorSapienza","indices":[88,100]},{"text":"Rosetta","indices":[103,111]}],"symbols":[],"user_mentions":[{"screen_name":"dsdanyds","name":"daniela sforza","id":406884842,"id_str":"406884842","indices":[3,12]}],"urls":[]}
#
# [75067 rows x 17 columns]

# %%
''' Creates new CSV file with the cleaned dataset to use in analysis ''' 
def createCleanedCSV(df):
    df.to_csv("./data/CleanedCometLanding.csv", index=False)

# %%
createCleanedCSV(df)

# %%
def main():
    #77319 rows × 17 columns original data
    df = pd.read_csv('CometLanding.csv')
    df = basicDataCleaning(df)
    

if __name__ == "__main__":
    main()
